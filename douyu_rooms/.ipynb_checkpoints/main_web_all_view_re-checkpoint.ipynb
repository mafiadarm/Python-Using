# %%
import re
import os
import requests
import json
import logging
from multiprocessing.dummy import Pool

LOG_FORMAT = "%(asctime)s - %(levelname)s - %(message)s"
logging.basicConfig(filename='douyu.log', level=logging.INFO, format=LOG_FORMAT)


def room_ids(page_count):
    rex = r'"rid":(.*?),'
    for i in range(1, page_count+1):
        url_head = f'https://www.douyu.com/gapi/rkc/directory/0_0/{i}'
        t_res = requests.get(url_head, headers=header)
        yield re.findall(rex, t_res.text)
    
    
def save(content):
    with open('douyu_topic.txt', 'a+') as ww:
        ww.write(f'{content}\n')

def save_lines(file_name, content):
    with open(file_name, 'w') as ww:
        ww.writelines(content)

        
def load(file_name):
    with open(file_name, 'r+') as rr:
        content = rr.readlines()
    return [i.replace("\n", "") for i in content]


def douyu_url():
    uu = read_room()
    dy_url_list = [f'https://www.douyu.com/topic/{k}?rid={rid}' for k, v in uu.items() for rid in v]
    return dy_url_list

        
def update(rid):
    rex = r'window.zhtName="(.*?)",window.room_ids=\[(".*?")\],'
    rid_url = f'https://www.douyu.com/{rid}'
    r_res = requests.get(rid_url, headers=header)
    logging.info(f'开始测试 {rid}')
    title_rooms = re.findall(rex, r_res.text)
    if title_rooms:
        url_info = f'https://www.douyu.com/topic/{title_rooms[0][0]}?rid={rid}'
        logging.info(f'已获取到 {url_info}')
        # k, v = title_rooms[0][0], title_rooms[0][1].replace('"', '').split(",")
        save(title_rooms[0][0])  # 只记录k

        
def compare():
    new = load('douyu_topic.txt')
    old = load('douyu_topic_old.txt')
    ing = set(new) ^ set(old)
    
    if not ing:
        print('no room close')
        print('no room open')
        return
    
    close = set(old) & ing
    if close:
        for c in close:
            print(f'close: {"https://douyu.com/topic/" + c}')
            logging.info(f'close: {"https://douyu.com/topic/" + c}')

    else:
        print('no room close')
              
    open_ = set(new) & ing
    if open_:
        for o in open_:
            print(f'open: {"https://douyu.com/topic/" + o}')
            logging.info(f'open: {"https://douyu.com/topic/" + o}')
    else:
        print('no room open')

    _n = '\n'.join(list(set(new)))
    save_lines('douyu_topic_old.txt', _n)
    save_lines('douyu_topic.txt', '')   
    

header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36'
}

# 获取主站翻页数
main_web = 'https://www.douyu.com/directory/all'
web_res = requests.get(main_web, headers=header)

rex = r'"pageCount":(\d+),'
page_count = int(re.findall(rex, web_res.text)[0])        
 
    
if not os.path.exists('douyu_topic_old.txt'):
    with open('douyu_topic_old.txt', 'w') as ww_init:
        ww_init.write('')
        
if not os.path.exists('douyu_topic.txt'):
    with open('douyu_topic.txt', 'w') as ww_init:
        ww_init.write('')  
        

pool = Pool(16)
for index, rids in enumerate(room_ids(page_count), 1):
    logging.info(f'------------开始扫描第 {index}/{page_count} 页------------')
    for rid in rids:
        pool.apply_async(update, (rid,))
        
pool.close()
pool.join()

compare()
input("按任意键关闭......")

# %%
def compare():
    new = load('douyu_topic.txt')
    old = load('douyu_topic_old.txt')
    ing = set(new) ^ set(old)
    
    if not ing:
        print('no room close')
        print('no room open')
        return
    
    close = set(old) & ing
    if close:
        for c in close:
            print(f'close: {"https://douyu.com/topic" + c}')
            logging.info(f'close: {"https://douyu.com/topic" + c}')

    else:
        print('no room close')
              
    open_ = set(new) & ing
    if open_:
        for o in open_:
            print(f'open: {"https://douyu.com/topic" + o}')
            logging.info(f'open: {"https://douyu.com/topic" + o}')
    else:
        print('no room open')

    _n = '\n'.join(list(set(new)))
    save_lines('douyu_topic_old.txt', _n)
    save_lines('douyu_topic.txt', '')   
    
compare()
# Out:
# INFO:root:open: https://douyu.com/topiccsgo_elisa2021summer
# INFO:root:open: https://douyu.com/topicwynext
# INFO:root:open: https://douyu.com/topicxrxdj
# INFO:root:open: https://douyu.com/topicDBLryjyh
# INFO:root:open: https://douyu.com/topicydlzn
# INFO:root:open: https://douyu.com/topicyjdjs
# INFO:root:open: https://douyu.com/topicCFMDHJ
# INFO:root:open: https://douyu.com/topicCFTALK
# INFO:root:open: https://douyu.com/topicdycpjm
# INFO:root:open: https://douyu.com/topicyzzsS5
# INFO:root:open: https://douyu.com/topicgyyyh_hpjy
# INFO:root:open: https://douyu.com/topicgqdfzz
# INFO:root:open: https://douyu.com/topicCFZBJLP
# INFO:root:open: https://douyu.com/topic2021wgjx
# INFO:root:open: https://douyu.com/topicmlxc
# INFO:root:open: https://douyu.com/topicblizzardtv
# INFO:root:open: https://douyu.com/topicCFPLS18
# INFO:root:open: https://douyu.com/topicxjsxb
# INFO:root:open: https://douyu.com/topicwstzz
# INFO:root:open: https://douyu.com/topicLPLXJS
# INFO:root:open: https://douyu.com/topichxtqra
# INFO:root:open: https://douyu.com/topic2021LDLXJS
# INFO:root:open: https://douyu.com/topichpjywb
# INFO:root:open: https://douyu.com/topicdyxgcft
# INFO:root:open: https://douyu.com/topicxqd
# INFO:root:open: https://douyu.com/topicapexfuli
# INFO:root:open: https://douyu.com/topicjy
# INFO:root:open: https://douyu.com/topicwzrywegl
# INFO:root:open: https://douyu.com/topicyqzx
# INFO:root:open: https://douyu.com/topic2021Popkart_M_P1SPRING
# INFO:root:open: https://douyu.com/topicsxhddmx
# INFO:root:open: https://douyu.com/topicjdqstcxb_pc
# INFO:root:open: https://douyu.com/topicComedyMonth
# INFO:root:open: https://douyu.com/topicZNQDNF
# INFO:root:open: https://douyu.com/topic2021LCSXJS
# INFO:root:open: https://douyu.com/topicdftankzm
# INFO:root:open: https://douyu.com/topicwdsjqwsc
# INFO:root:open: https://douyu.com/topicCFMLS10
# INFO:root:open: https://douyu.com/topicPSIS1
# INFO:root:open: https://douyu.com/topicNEXT2021SPRING
